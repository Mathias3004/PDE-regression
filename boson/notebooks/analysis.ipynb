# %%
# necessary imports

import numpy as np
from numpy import linalg as LA

import scipy.sparse as sparse
from scipy.sparse import csc_matrix
from scipy.sparse import dia_matrix
from scipy import interpolate

import matplotlib.pyplot as plt
import matplotlib
import pickle
import sys

import itertools
import functools
import progressbar
import operator
import time

from importlib import reload
from functions_regression import *
from functions_PDE_solver import *

folder = 'store'

# %%
# !ls "$folder"
# Out:
# data_infinite_N_20_V0_-0.01_U_0.10_J_0.50_T_20.00.pkl

# %%
# to load saved data for analysis (check ls above)
N_site = 20 # number of sites
V0 = -0.01 # depth starting potential (deeper for larger U to still contain all particles in dip)
U = 0.1 # interaction
J = 0.5 # hopping
t_ev = 20. # evolution time
prefix = "/data_infinite"


suffix = str(N_site) + "_V0_" + "{:.2f}".format(V0) + "_U_" + "{:.2f}".format(U) + "_J_" + "{:.2f}".format(J) + "_T_" + "{:.2f}".format(t_ev)
filename = prefix + "_N_" + suffix

with open(folder + filename + '.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
i_t = 0

# plot a few data panels
fig, ax = plt.subplots(1,4,figsize=(20,5))

S = np.array(data['entropy'][:][:])
ax[0].plot(data['t'][:],S[:,N_site//2])
ax[0].set_xlabel('time')
ax[0].set_ylabel('S')
ax[0].set_title("Half-chain entropy over time")

N = np.array(data['N'][i_t][:])
ax[1].plot(N)
ax[1].set_xlabel('site i')
ax[1].set_ylabel('N')
ax[1].set_title("Density profile t={:.2f}".format(data['t'][i_t]))

g1 = np.array(data['g1'][i_t][N_site//2][:])
ax[2].plot(g1)
ax[2].set_xlabel('site i')
ax[2].set_ylabel(r'$C_{ij}$')
ax[2].set_title(r'Correlation $g_1=\langle a^\dagger_{N/2} a_i \rangle$ t=' + '{:.2f}'.format(data['t'][i_t]))
dens_corr = np.array(data['g2'][i_t][N_site//2][:])

dens_corr[N_site//2] -= N[N_site//2] # for commutator
g2 = dens_corr / N[N_site//2] / (N + 1e-5) # normalize with densities

ax[3].plot(g2)
ax[3].set_xlabel('site i')
ax[3].set_ylabel(r'$C_{ij}$')
ax[3].set_title(r'Correlation $g_2=\langle a^\dagger_{N/2}a^\dagger_{i} a_i a_{N/2}\rangle$ t=' + '{:.2f}'.format(data['t'][i_t]))
# Out:
# /opt/packages/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'Correlation $g_2=\\langle a^\\dagger_{N/2}a^\\dagger_{i} a_i a_{N/2}\\rangle$ t=0.00')

# %%
# data to use
u = np.array(data['g1'])
ts = np.array(data['t'])

# plot a few data panels
fig, ax = plt.subplots(1,6,figsize=(23,3))

it_plot = np.array([0, .25, .50, .75, 1.]) * (len(data['t'])-1)
it_plot = it_plot.astype(int)                                                   

pcm = ax[0].pcolormesh(np.arange(N_site),ts,np.real(u[:,:,N_site//2]), shading='auto')
clb = fig.colorbar(pcm, ax=ax[0])
ax[0].set_title("timeline (x,N/2)")


for i, it in enumerate(list(it_plot)):
    pcm = ax[i+1].pcolormesh(np.real(u[it]))
    ax[i+1].set_title("t=" + "{:.2f}".format(ts[it]))
    fig.colorbar(pcm, ax=ax[i+1])

# %%
# evaluate Theta (symmetric terms only)

# select fraction of u for analysis
it_start = 0
it_end = 10

x_range = 50

Nt, Nx, Ny = u.shape

# index for selecting elements all variable for analysis
t = ts[it_start:it_end]
indx = (slice(it_start,it_end), slice(N_site//2-x_range,N_site//2+x_range+1), slice(N_site//2-x_range,N_site//2+x_range+1))
m, n, o = u[indx].shape

# differentials
dt = t[1]-t[0]
dx = 1.

bc = 'periodic'

# start dictionaries for all variables regression
dic_t = dict([])

dic_t['u_t'] = MultiFiniteDiff_t(u, dt, d=1)
dic_t['u_tt'] = MultiFiniteDiff_t(u, dt, d=2)

dic_v = dict([])

# spatial x and y derivatives
u_x = MultiFiniteDiff(u, dx, 1, axis=1, bc=bc)
u_xx = MultiFiniteDiff(u, dx, 2, axis=1, bc=bc)
u_xxx = MultiFiniteDiff(u, dx, 3, axis=1, bc=bc)
u_xxxx = MultiFiniteDiff(u, dx, 4, axis=1, bc=bc)

u_y = MultiFiniteDiff(u, dx, 1, axis=2, bc=bc)
u_yy = MultiFiniteDiff(u, dx, 2, axis=2, bc=bc)
u_yyy = MultiFiniteDiff(u, dx, 3, axis=2, bc=bc)
u_yyyy = MultiFiniteDiff(u, dx, 4, axis=2, bc=bc)

# density
nx = []
ny = []

for i in range(Nt):
  dens = np.diag(u[i,:,:])
  nx.append( np.tile(dens, (Nx,1)).T )
  ny.append( np.tile(dens, (Nx,1)) )
nx = np.array(nx)
ny = np.array(ny)

nx_x = MultiFiniteDiff(nx, dx, 1, axis=1, bc=bc)
ny_y = MultiFiniteDiff(ny, dx, 1, axis=2, bc=bc)

# symmetric and antisymmetric combinations to include
dic_v['u_xx-u_yy'] = u_xx - u_yy
dic_v['u_xx+u_yy'] = u_xx + u_yy
dic_v['u_xxxx-u_yyyy'] = u_xxxx - u_yyyy
dic_v['u_xxxx+u_yyyy'] = u_xxxx + u_yyyy
dic_v['nx*u-ny*u'] = (nx-ny)*u
dic_v['u_x^2-u_y^2'] = u_x**2-u_y**2
dic_v['uc_x*u_x-uc_y*u_y'] = np.abs(u_x)**2 - np.abs(u_y)**2
dic_v['nx_x*u_x-ny_y*u_y'] = nx_x*u_x - ny_y*u_y
dic_v['nx_x*u_y-ny_y*u_x'] = nx_x*u_y - ny_y*u_x
dic_v['nx*u_xx-ny*u_yy'] = nx*u_xx - ny*u_yy
dic_v['nx*u_xx+ny*u_yy'] = nx*u_xx + ny*u_yy
dic_v['ny*u_xx-nx*u_yy'] = nx*u_xx - ny*u_yy
dic_v['ny*u_xx+nx*u_yy'] = nx*u_xx + ny*u_yy



# select intervals, resize and add to stacks
X_data = np.hstack([u[indx].reshape((m*n*o),1)])
data_description = ['u']

X_list, derivatives_description = [], []
for key, var in dic_v.items():
  X_list.append( var[indx].reshape((m*n*o,1)) )
  derivatives_description.append( key )
X_ders = np.hstack(X_list)

# build theta
X, descr = build_custom_Theta(X_data, X_ders, derivatives_description, 
                       data_description = data_description)

print(descr)
# Out:
# ['', 'u', 'u_xx-u_yy', 'u_xx+u_yy', 'u_xxxx-u_yyyy', 'u_xxxx+u_yyyy', 'nx*u-ny*u', 'u_x^2-u_y^2', 'uc_x*u_x-uc_y*u_y', 'nx_x*u_x-ny_y*u_y', 'nx_x*u_y-ny_y*u_x', 'nx*u_xx-ny*u_yy', 'nx*u_xx+ny*u_yy', 'ny*u_xx-nx*u_yy', 'ny*u_xx+nx*u_yy']

# %%
# plot all columns of theta and check for symmetries, anomalies etc and pick the terms you want to add in the fitting
n_panel = len(descr)+2

n_row = 4
n_col = int(np.ceil(n_panel/n_row))


fig, ax = plt.subplots(n_col,n_row,figsize=(n_row*3,n_col * 3))

i = 0
for k in range(n_col):
  for l in range(n_row):
    if i < X.shape[1]:
      pcm = ax[k,l].pcolormesh(np.real(X[:,i]).reshape((m,n,o))[:,n//2,:])
      fig.colorbar(pcm,ax=ax[k,l])
      ax[k,l].set_title(str(i) + ": " + descr[i])
    # u_t
    elif i == X.shape[1]:
      pcm = ax[k,l].pcolormesh(np.real(dic_t['u_t'])[:,n//2,:])
      fig.colorbar(pcm,ax=ax[k,l])
      ax[k,l].set_title("u_t")
    # u_tt
    elif i == X.shape[1]+1:
      pcm = ax[k,l].pcolormesh(np.real(dic_t['u_tt'])[:,n//2,:])
      fig.colorbar(pcm,ax=ax[k,l])
      ax[k,l].set_title("u_tt")

    i += 1

fig.tight_layout()

# %%
# select terms from pictures to include in search (discard all options that are almost zero or do not satisfy symmetries)

# big selection
#i_theta_select = (10,11,12,13,14,19,26)

# check quick

theta_search = ['u','u_xx-u_yy','u_x^2-u_y^2', 'uc_x*u_x-uc_y*u_y', 'nx_x*u_x-ny_y*u_y', 'nx_x*u_y-ny_y*u_x','u_xxxx-u_yyyy']
theta_fix = ['u_xx-u_yy','nx*u-ny*u']
#theta_search = ['nx*u-ny*u']

#theta_select = descr[2:]
theta_select = theta_fix + theta_search
i_theta_select = []
for name in theta_select:
  i_theta_select.append( descr.index(name) )

i_theta_select
# Out:
# [2, 6, 1, 2, 7, 8, 9, 10, 4]

# %%
# u_t Brute Force

import functions_regression
reload( functions_regression )
from functions_regression import *

l0 = .01

X_select = X.take(i_theta_select, axis=1)
descr_select = list(np.take(descr, i_theta_select))

ut = dic_t['u_t'][it_start:it_end].reshape((m*n*o,1))

train_data_t = BruteForceL0(X_select, ut, descr_select, l0_penalty=l0, lam_l2=0., verbose=1, lhs_descr="u_t", fixed_columns=theta_fix)
#train_data_tt = BruteForceL0(X_select, utt, descr_select, l0_penalty=.01, lam_l2=0., verbose=1, lhs_descr="u_tt")
# Out:
# Brute Force search with l0_penalty 0.01
# iteration 0 from total 128
# Current PDE
# u_t = (-0.000309 -0.059412i)u_xx-u_yy
#     + (-0.001173 +0.129647i)nx*u-ny*u
#     + (-0.000275 +0.000001i)u
#     + (-0.000309 -0.059412i)u_xx-u_yy
#     + (-0.283401 -4.299173i)u_x^2-u_y^2
#     + (0.292442 +4.601927i)uc_x*u_x-uc_y*u_y
#     + (-0.075962 -13.921616i)nx_x*u_x-ny_y*u_y
#     + (0.334315 -6.573379i)nx_x*u_y-ny_y*u_x
#     + (-0.000090 -0.030550i)u_xxxx-u_yyyy
#
# Error 0.13783714157481158, Error best: 0.13783714157481158, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000309 -0.059412i)u_xx-u_yy
#     + (-0.001173 +0.129647i)nx*u-ny*u
#     + (-0.000275 +0.000001i)u
#     + (-0.000309 -0.059412i)u_xx-u_yy
#     + (-0.283401 -4.299173i)u_x^2-u_y^2
#     + (0.292442 +4.601927i)uc_x*u_x-uc_y*u_y
#     + (-0.075962 -13.921616i)nx_x*u_x-ny_y*u_y
#     + (0.334315 -6.573379i)nx_x*u_y-ny_y*u_x
#     + (-0.000090 -0.030550i)u_xxxx-u_yyyy
#
# iteration 1 from total 128
# Current PDE
# u_t = (-0.000184 -0.009586i)u_xx-u_yy
#     + (-0.001312 +0.141338i)nx*u-ny*u
#     + (-0.000282 +0.000003i)u
#     + (-0.000184 -0.009586i)u_xx-u_yy
#     + (-0.337329 -4.754956i)u_x^2-u_y^2
#     + (0.348333 +4.830059i)uc_x*u_x-uc_y*u_y
#     + (-0.100405 -13.721618i)nx_x*u_x-ny_y*u_y
#     + (0.392384 -7.427232i)nx_x*u_y-ny_y*u_x
#
# Error 0.13042456907112043, Error best: 0.13042456907112043, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000184 -0.009586i)u_xx-u_yy
#     + (-0.001312 +0.141338i)nx*u-ny*u
#     + (-0.000282 +0.000003i)u
#     + (-0.000184 -0.009586i)u_xx-u_yy
#     + (-0.337329 -4.754956i)u_x^2-u_y^2
#     + (0.348333 +4.830059i)uc_x*u_x-uc_y*u_y
#     + (-0.100405 -13.721618i)nx_x*u_x-ny_y*u_y
#     + (0.392384 -7.427232i)nx_x*u_y-ny_y*u_x
#
# iteration 2 from total 128
# Current PDE
# u_t = (-0.000348 -0.060193i)u_xx-u_yy
#     + (-0.000715 +0.121195i)nx*u-ny*u
#     + (-0.000256 +0.000000i)u
#     + (-0.000348 -0.060193i)u_xx-u_yy
#     + (-0.186911 -5.646223i)u_x^2-u_y^2
#     + (0.185796 +6.160063i)uc_x*u_x-uc_y*u_y
#     + (-0.239747 -10.687900i)nx_x*u_x-ny_y*u_y
#     + (-0.000103 -0.031174i)u_xxxx-u_yyyy
#
# Error 0.12866742821836735, Error best: 0.12866742821836735, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000348 -0.060193i)u_xx-u_yy
#     + (-0.000715 +0.121195i)nx*u-ny*u
#     + (-0.000256 +0.000000i)u
#     + (-0.000348 -0.060193i)u_xx-u_yy
#     + (-0.186911 -5.646223i)u_x^2-u_y^2
#     + (0.185796 +6.160063i)uc_x*u_x-uc_y*u_y
#     + (-0.239747 -10.687900i)nx_x*u_x-ny_y*u_y
#     + (-0.000103 -0.031174i)u_xxxx-u_yyyy
#
# iteration 3 from total 128
# Current PDE
# u_t = (-0.000207 -0.009319i)u_xx-u_yy
#     + (-0.000773 +0.132033i)nx*u-ny*u
#     + (-0.000260 +0.000002i)u
#     + (-0.000207 -0.009319i)u_xx-u_yy
#     + (-0.226409 -6.291489i)u_x^2-u_y^2
#     + (0.225402 +6.600469i)uc_x*u_x-uc_y*u_y
#     + (-0.293676 -10.053498i)nx_x*u_x-ny_y*u_y
#
# Error 0.12135200683873987, Error best: 0.12135200683873987, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000207 -0.009319i)u_xx-u_yy
#     + (-0.000773 +0.132033i)nx*u-ny*u
#     + (-0.000260 +0.000002i)u
#     + (-0.000207 -0.009319i)u_xx-u_yy
#     + (-0.226409 -6.291489i)u_x^2-u_y^2
#     + (0.225402 +6.600469i)uc_x*u_x-uc_y*u_y
#     + (-0.293676 -10.053498i)nx_x*u_x-ny_y*u_y
#
# iteration 4 from total 128
# Current PDE
# u_t = (-0.000220 -0.057981i)u_xx-u_yy
#     + (-0.001059 +0.118616i)nx*u-ny*u
#     + (-0.000140 +0.000005i)u
#     + (-0.000220 -0.057981i)u_xx-u_yy
#     + (-0.354131 -7.581553i)u_x^2-u_y^2
#     + (0.362571 +7.975215i)uc_x*u_x-uc_y*u_y
#     + (0.374072 +1.003173i)nx_x*u_y-ny_y*u_x
#     + (-0.000046 -0.030210i)u_xxxx-u_yyyy
#
# Error 0.13055881137558825, Error best: 0.12135200683873987, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000207 -0.009319i)u_xx-u_yy
#     + (-0.000773 +0.132033i)nx*u-ny*u
#     + (-0.000260 +0.000002i)u
#     + (-0.000207 -0.009319i)u_xx-u_yy
#     + (-0.226409 -6.291489i)u_x^2-u_y^2
#     + (0.225402 +6.600469i)uc_x*u_x-uc_y*u_y
#     + (-0.293676 -10.053498i)nx_x*u_x-ny_y*u_y
#
# iteration 5 from total 128
# Current PDE
# u_t = (-0.000167 -0.008723i)u_xx-u_yy
#     + (-0.001235 +0.130334i)nx*u-ny*u
#     + (-0.000149 +0.000007i)u
#     + (-0.000167 -0.008723i)u_xx-u_yy
#     + (-0.411834 -7.985677i)u_x^2-u_y^2
#     + (0.422715 +8.152905i)uc_x*u_x-uc_y*u_y
#     + (0.446053 +0.051161i)nx_x*u_y-ny_y*u_x
#
# Error 0.12282694802398578, Error best: 0.12135200683873987, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000207 -0.009319i)u_xx-u_yy
#     + (-0.000773 +0.132033i)nx*u-ny*u
#     + (-0.000260 +0.000002i)u
#     + (-0.000207 -0.009319i)u_xx-u_yy
#     + (-0.226409 -6.291489i)u_x^2-u_y^2
#     + (0.225402 +6.600469i)uc_x*u_x-uc_y*u_y
#     + (-0.293676 -10.053498i)nx_x*u_x-ny_y*u_y
#
# iteration 6 from total 128
# Current PDE
# u_t = (-0.000114 -0.057757i)u_xx-u_yy
#     + (-0.000598 +0.119843i)nx*u-ny*u
#     + (-0.000137 +0.000005i)u
#     + (-0.000114 -0.057757i)u_xx-u_yy
#     + (-0.317000 -7.456295i)u_x^2-u_y^2
#     + (0.310506 +7.810437i)uc_x*u_x-uc_y*u_y
#     + (0.000020 -0.030068i)u_xxxx-u_yyyy
#
# Error 0.1204856909492767, Error best: 0.1204856909492767, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000114 -0.057757i)u_xx-u_yy
#     + (-0.000598 +0.119843i)nx*u-ny*u
#     + (-0.000137 +0.000005i)u
#     + (-0.000114 -0.057757i)u_xx-u_yy
#     + (-0.317000 -7.456295i)u_x^2-u_y^2
#     + (0.310506 +7.810437i)uc_x*u_x-uc_y*u_y
#     + (0.000020 -0.030068i)u_xxxx-u_yyyy
#
# iteration 7 from total 128
# Current PDE
# u_t = (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.000712 +0.130395i)nx*u-ny*u
#     + (-0.000148 +0.000006i)u
#     + (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.356828 -7.975756i)u_x^2-u_y^2
#     + (0.350509 +8.141058i)uc_x*u_x-uc_y*u_y
#
# Error 0.11279723923696391, Error best: 0.11279723923696391, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.000712 +0.130395i)nx*u-ny*u
#     + (-0.000148 +0.000006i)u
#     + (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.356828 -7.975756i)u_x^2-u_y^2
#     + (0.350509 +8.141058i)uc_x*u_x-uc_y*u_y
#
# iteration 8 from total 128
# Current PDE
# u_t = (-0.000277 -0.060152i)u_xx-u_yy
#     + (-0.000877 +0.137586i)nx*u-ny*u
#     + (-0.000221 -0.000002i)u
#     + (-0.000277 -0.060152i)u_xx-u_yy
#     + (-0.002002 +0.162644i)u_x^2-u_y^2
#     + (-0.161714 -15.701829i)nx_x*u_x-ny_y*u_y
#     + (0.178145 -8.497541i)nx_x*u_y-ny_y*u_x
#     + (-0.000054 -0.030759i)u_xxxx-u_yyyy
#
# Error 0.12827377887931724, Error best: 0.11279723923696391, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.000712 +0.130395i)nx*u-ny*u
#     + (-0.000148 +0.000006i)u
#     + (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.356828 -7.975756i)u_x^2-u_y^2
#     + (0.350509 +8.141058i)uc_x*u_x-uc_y*u_y
#
# iteration 9 from total 128
# Current PDE
# u_t = (-0.000217 -0.010006i)u_xx-u_yy
#     + (-0.000945 +0.149758i)nx*u-ny*u
#     + (-0.000226 -0.000001i)u
#     + (-0.000217 -0.010006i)u_xx-u_yy
#     + (-0.001562 -0.073616i)u_x^2-u_y^2
#     + (-0.206861 -15.589581i)nx_x*u_x-ny_y*u_y
#     + (0.212538 -9.453242i)nx_x*u_y-ny_y*u_x
#
# Error 0.12090240500502465, Error best: 0.11279723923696391, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.000712 +0.130395i)nx*u-ny*u
#     + (-0.000148 +0.000006i)u
#     + (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.356828 -7.975756i)u_x^2-u_y^2
#     + (0.350509 +8.141058i)uc_x*u_x-uc_y*u_y
#
# iteration 10 from total 128
# Current PDE
# u_t = (-0.000315 -0.061625i)u_xx-u_yy
#     + (-0.000831 +0.129303i)nx*u-ny*u
#     + (-0.000168 -0.000003i)u
#     + (-0.000315 -0.061625i)u_xx-u_yy
#     + (-0.005933 +0.397362i)u_x^2-u_y^2
#     + (-0.211492 -11.924725i)nx_x*u_x-ny_y*u_y
#     + (-0.000070 -0.031750i)u_xxxx-u_yyyy
#
# Error 0.11981545177405453, Error best: 0.11279723923696391, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.000712 +0.130395i)nx*u-ny*u
#     + (-0.000148 +0.000006i)u
#     + (-0.000170 -0.008724i)u_xx-u_yy
#     + (-0.356828 -7.975756i)u_x^2-u_y^2
#     + (0.350509 +8.141058i)uc_x*u_x-uc_y*u_y
#
# iteration 11 from total 128
# Current PDE
# u_t = (-0.000230 -0.009845i)u_xx-u_yy
#     + (-0.000877 +0.140948i)nx*u-ny*u
#     + (-0.000167 -0.000002i)u
#     + (-0.000230 -0.009845i)u_xx-u_yy
#     + (-0.006448 +0.179947i)u_x^2-u_y^2
#     + (-0.270414 -11.368260i)nx_x*u_x-ny_y*u_y
#
# Error 0.11262354384731076, Error best: 0.11262354384731076, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000230 -0.009845i)u_xx-u_yy
#     + (-0.000877 +0.140948i)nx*u-ny*u
#     + (-0.000167 -0.000002i)u
#     + (-0.000230 -0.009845i)u_xx-u_yy
#     + (-0.006448 +0.179947i)u_x^2-u_y^2
#     + (-0.270414 -11.368260i)nx_x*u_x-ny_y*u_y
#
# iteration 12 from total 128
# Current PDE
# u_t = (-0.000103 -0.059042i)u_xx-u_yy
#     + (-0.000805 +0.131091i)nx*u-ny*u
#     + (-0.000005 +0.000002i)u
#     + (-0.000103 -0.059042i)u_xx-u_yy
#     + (-0.007425 +0.147909i)u_x^2-u_y^2
#     + (0.197446 -0.825192i)nx_x*u_y-ny_y*u_x
#     + (0.000044 -0.030523i)u_xxxx-u_yyyy
#
# Error 0.12214660009986134, Error best: 0.11262354384731076, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000230 -0.009845i)u_xx-u_yy
#     + (-0.000877 +0.140948i)nx*u-ny*u
#     + (-0.000167 -0.000002i)u
#     + (-0.000230 -0.009845i)u_xx-u_yy
#     + (-0.006448 +0.179947i)u_x^2-u_y^2
#     + (-0.270414 -11.368260i)nx_x*u_x-ny_y*u_y
#
# iteration 13 from total 128
# Current PDE
# u_t = (-0.000201 -0.009285i)u_xx-u_yy
#     + (-0.000931 +0.143216i)nx*u-ny*u
#     + (-0.000011 +0.000002i)u
#     + (-0.000201 -0.009285i)u_xx-u_yy
#     + (-0.006244 -0.086435i)u_x^2-u_y^2
#     + (0.257097 -1.827713i)nx_x*u_y-ny_y*u_x
#
# Error 0.11441782923945715, Error best: 0.11262354384731076, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000230 -0.009845i)u_xx-u_yy
#     + (-0.000877 +0.140948i)nx*u-ny*u
#     + (-0.000167 -0.000002i)u
#     + (-0.000230 -0.009845i)u_xx-u_yy
#     + (-0.006448 +0.179947i)u_x^2-u_y^2
#     + (-0.270414 -11.368260i)nx_x*u_x-ny_y*u_y
#
# iteration 14 from total 128
# Current PDE
# u_t = (-0.000065 -0.059261i)u_xx-u_yy
#     + (-0.000624 +0.130253i)nx*u-ny*u
#     + (-0.000005 +0.000001i)u
#     + (-0.000065 -0.059261i)u_xx-u_yy
#     + (-0.014213 +0.177531i)u_x^2-u_y^2
#     + (0.000068 -0.030655i)u_xxxx-u_yyyy
#
# Error 0.11223201060683524, Error best: 0.11223201060683524, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000065 -0.059261i)u_xx-u_yy
#     + (-0.000624 +0.130253i)nx*u-ny*u
#     + (-0.000005 +0.000001i)u
#     + (-0.000065 -0.059261i)u_xx-u_yy
#     + (-0.014213 +0.177531i)u_x^2-u_y^2
#     + (0.000068 -0.030655i)u_xxxx-u_yyyy
#
# iteration 15 from total 128
# Current PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# Error 0.10463025667066617, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 16 from total 128
# Current PDE
# u_t = (-0.000302 -0.060417i)u_xx-u_yy
#     + (-0.000885 +0.137058i)nx*u-ny*u
#     + (-0.000223 -0.000002i)u
#     + (-0.000302 -0.060417i)u_xx-u_yy
#     + (0.005348 +0.278199i)uc_x*u_x-uc_y*u_y
#     + (-0.159531 -15.600497i)nx_x*u_x-ny_y*u_y
#     + (0.194502 -8.185339i)nx_x*u_y-ny_y*u_x
#     + (-0.000071 -0.030950i)u_xxxx-u_yyyy
#
# Error 0.12828481263005742, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 17 from total 128
# Current PDE
# u_t = (-0.000215 -0.009976i)u_xx-u_yy
#     + (-0.000962 +0.149716i)nx*u-ny*u
#     + (-0.000224 -0.000001i)u
#     + (-0.000215 -0.009976i)u_xx-u_yy
#     + (0.006960 +0.044616i)uc_x*u_x-uc_y*u_y
#     + (-0.202784 -15.578349i)nx_x*u_x-ny_y*u_y
#     + (0.229977 -9.224748i)nx_x*u_y-ny_y*u_x
#
# Error 0.12094736977251264, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 18 from total 128
# Current PDE
# u_t = (-0.000335 -0.061889i)u_xx-u_yy
#     + (-0.000800 +0.128779i)nx*u-ny*u
#     + (-0.000176 -0.000003i)u
#     + (-0.000335 -0.061889i)u_xx-u_yy
#     + (-0.001047 +0.552492i)uc_x*u_x-uc_y*u_y
#     + (-0.219323 -11.946498i)nx_x*u_x-ny_y*u_y
#     + (-0.000083 -0.031957i)u_xxxx-u_yyyy
#
# Error 0.11971650436484337, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 19 from total 128
# Current PDE
# u_t = (-0.000229 -0.009786i)u_xx-u_yy
#     + (-0.000854 +0.140813i)nx*u-ny*u
#     + (-0.000171 -0.000002i)u
#     + (-0.000229 -0.009786i)u_xx-u_yy
#     + (-0.000659 +0.346424i)uc_x*u_x-uc_y*u_y
#     + (-0.276862 -11.442401i)nx_x*u_x-ny_y*u_y
#
# Error 0.11257344833565608, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 20 from total 128
# Current PDE
# u_t = (-0.000141 -0.059594i)u_xx-u_yy
#     + (-0.000815 +0.130417i)nx*u-ny*u
#     + (-0.000008 +0.000001i)u
#     + (-0.000141 -0.059594i)u_xx-u_yy
#     + (0.002583 +0.367190i)uc_x*u_x-uc_y*u_y
#     + (0.216660 -0.354772i)nx_x*u_y-ny_y*u_x
#     + (0.000020 -0.030906i)u_xxxx-u_yyyy
#
# Error 0.12216619641579601, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 21 from total 128
# Current PDE
# u_t = (-0.000199 -0.009228i)u_xx-u_yy
#     + (-0.000947 +0.143066i)nx*u-ny*u
#     + (-0.000010 +0.000002i)u
#     + (-0.000199 -0.009228i)u_xx-u_yy
#     + (0.005125 +0.133833i)uc_x*u_x-uc_y*u_y
#     + (0.276904 -1.403452i)nx_x*u_y-ny_y*u_x
#
# Error 0.11450018926330763, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 22 from total 128
# Current PDE
# u_t = (-0.000090 -0.059691i)u_xx-u_yy
#     + (-0.000593 +0.130037i)nx*u-ny*u
#     + (-0.000008 +0.000001i)u
#     + (-0.000090 -0.059691i)u_xx-u_yy
#     + (-0.006016 +0.381375i)uc_x*u_x-uc_y*u_y
#     + (0.000051 -0.030964i)u_xxxx-u_yyyy
#
# Error 0.1121955967090984, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 23 from total 128
# Current PDE
# u_t = (-0.000201 -0.009230i)u_xx-u_yy
#     + (-0.000696 +0.141660i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000201 -0.009230i)u_xx-u_yy
#     + (-0.005543 +0.188458i)uc_x*u_x-uc_y*u_y
#
# Error 0.10464850372837481, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 24 from total 128
# Current PDE
# u_t = (-0.000281 -0.059681i)u_xx-u_yy
#     + (-0.000864 +0.137661i)nx*u-ny*u
#     + (-0.000224 -0.000002i)u
#     + (-0.000281 -0.059681i)u_xx-u_yy
#     + (-0.165114 -15.692648i)nx_x*u_x-ny_y*u_y
#     + (0.183058 -8.794828i)nx_x*u_y-ny_y*u_x
#     + (-0.000056 -0.030448i)u_xxxx-u_yyyy
#
# Error 0.11821187113387288, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 25 from total 128
# Current PDE
# u_t = (-0.000217 -0.009989i)u_xx-u_yy
#     + (-0.000951 +0.149781i)nx*u-ny*u
#     + (-0.000225 -0.000001i)u
#     + (-0.000217 -0.009989i)u_xx-u_yy
#     + (-0.205638 -15.593325i)nx_x*u_x-ny_y*u_y
#     + (0.214917 -9.321095i)nx_x*u_y-ny_y*u_x
#
# Error 0.1109336833219822, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 26 from total 128
# Current PDE
# u_t = (-0.000332 -0.060547i)u_xx-u_yy
#     + (-0.000797 +0.128751i)nx*u-ny*u
#     + (-0.000170 -0.000003i)u
#     + (-0.000332 -0.060547i)u_xx-u_yy
#     + (-0.224167 -11.561123i)nx_x*u_x-ny_y*u_y
#     + (-0.000081 -0.031041i)u_xxxx-u_yyyy
#
# Error 0.10977327614387167, Error best: 0.10463025667066617, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.000203 -0.009294i)u_xx-u_yy
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 27 from total 128
# Current PDE
# u_t = (-0.000229 -0.009881i)u_xx-u_yy
#     + (-0.000850 +0.140576i)nx*u-ny*u
#     + (-0.000168 -0.000002i)u
#     + (-0.000229 -0.009881i)u_xx-u_yy
#     + (-0.278889 -11.207309i)nx_x*u_x-ny_y*u_y
#
# Error 0.10259549389416443, Error best: 0.10259549389416443, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000229 -0.009881i)u_xx-u_yy
#     + (-0.000850 +0.140576i)nx*u-ny*u
#     + (-0.000168 -0.000002i)u
#     + (-0.000229 -0.009881i)u_xx-u_yy
#     + (-0.278889 -11.207309i)nx_x*u_x-ny_y*u_y
#
# iteration 28 from total 128
# Current PDE
# u_t = (-0.000123 -0.058615i)u_xx-u_yy
#     + (-0.000798 +0.131163i)nx*u-ny*u
#     + (-0.000008 +0.000002i)u
#     + (-0.000123 -0.058615i)u_xx-u_yy
#     + (0.213858 -1.099532i)nx_x*u_y-ny_y*u_x
#     + (0.000031 -0.030241i)u_xxxx-u_yyyy
#
# Error 0.11207440588737708, Error best: 0.10259549389416443, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000229 -0.009881i)u_xx-u_yy
#     + (-0.000850 +0.140576i)nx*u-ny*u
#     + (-0.000168 -0.000002i)u
#     + (-0.000229 -0.009881i)u_xx-u_yy
#     + (-0.278889 -11.207309i)nx_x*u_x-ny_y*u_y
#
# iteration 29 from total 128
# Current PDE
# u_t = (-0.000200 -0.009266i)u_xx-u_yy
#     + (-0.000936 +0.143241i)nx*u-ny*u
#     + (-0.000010 +0.000002i)u
#     + (-0.000200 -0.009266i)u_xx-u_yy
#     + (0.267197 -1.670339i)nx_x*u_y-ny_y*u_x
#
# Error 0.10446229817765534, Error best: 0.10259549389416443, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000229 -0.009881i)u_xx-u_yy
#     + (-0.000850 +0.140576i)nx*u-ny*u
#     + (-0.000168 -0.000002i)u
#     + (-0.000229 -0.009881i)u_xx-u_yy
#     + (-0.278889 -11.207309i)nx_x*u_x-ny_y*u_y
#
# iteration 30 from total 128
# Current PDE
# u_t = (-0.000105 -0.058804i)u_xx-u_yy
#     + (-0.000594 +0.129990i)nx*u-ny*u
#     + (-0.000008 +0.000001i)u
#     + (-0.000105 -0.058804i)u_xx-u_yy
#     + (0.000042 -0.030348i)u_xxxx-u_yyyy
#
# Error 0.1021757583379169, Error best: 0.1021757583379169, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000105 -0.058804i)u_xx-u_yy
#     + (-0.000594 +0.129990i)nx*u-ny*u
#     + (-0.000008 +0.000001i)u
#     + (-0.000105 -0.058804i)u_xx-u_yy
#     + (0.000042 -0.030348i)u_xxxx-u_yyyy
#
# iteration 31 from total 128
# Current PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# Error 0.0946361271901821, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 32 from total 128
# Current PDE
# u_t = (-0.000618 -0.118825i)u_xx-u_yy
#     + (-0.001173 +0.129647i)nx*u-ny*u
#     + (-0.000275 +0.000001i)u
#     + (-0.283401 -4.299173i)u_x^2-u_y^2
#     + (0.292442 +4.601927i)uc_x*u_x-uc_y*u_y
#     + (-0.075962 -13.921616i)nx_x*u_x-ny_y*u_y
#     + (0.334315 -6.573379i)nx_x*u_y-ny_y*u_x
#     + (-0.000090 -0.030550i)u_xxxx-u_yyyy
#
# Error 0.12783714157481157, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 33 from total 128
# Current PDE
# u_t = (-0.000368 -0.019172i)u_xx-u_yy
#     + (-0.001312 +0.141338i)nx*u-ny*u
#     + (-0.000282 +0.000003i)u
#     + (-0.337329 -4.754956i)u_x^2-u_y^2
#     + (0.348333 +4.830059i)uc_x*u_x-uc_y*u_y
#     + (-0.100405 -13.721618i)nx_x*u_x-ny_y*u_y
#     + (0.392384 -7.427232i)nx_x*u_y-ny_y*u_x
#
# Error 0.12042456907112045, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 34 from total 128
# Current PDE
# u_t = (-0.000697 -0.120387i)u_xx-u_yy
#     + (-0.000715 +0.121195i)nx*u-ny*u
#     + (-0.000256 +0.000000i)u
#     + (-0.186911 -5.646223i)u_x^2-u_y^2
#     + (0.185796 +6.160063i)uc_x*u_x-uc_y*u_y
#     + (-0.239747 -10.687900i)nx_x*u_x-ny_y*u_y
#     + (-0.000103 -0.031174i)u_xxxx-u_yyyy
#
# Error 0.11866742821836736, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 35 from total 128
# Current PDE
# u_t = (-0.000414 -0.018638i)u_xx-u_yy
#     + (-0.000773 +0.132033i)nx*u-ny*u
#     + (-0.000260 +0.000002i)u
#     + (-0.226409 -6.291489i)u_x^2-u_y^2
#     + (0.225402 +6.600469i)uc_x*u_x-uc_y*u_y
#     + (-0.293676 -10.053498i)nx_x*u_x-ny_y*u_y
#
# Error 0.11135200683873986, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 36 from total 128
# Current PDE
# u_t = (-0.000441 -0.115962i)u_xx-u_yy
#     + (-0.001059 +0.118616i)nx*u-ny*u
#     + (-0.000140 +0.000005i)u
#     + (-0.354131 -7.581553i)u_x^2-u_y^2
#     + (0.362571 +7.975215i)uc_x*u_x-uc_y*u_y
#     + (0.374072 +1.003173i)nx_x*u_y-ny_y*u_x
#     + (-0.000046 -0.030210i)u_xxxx-u_yyyy
#
# Error 0.12055881137558827, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 37 from total 128
# Current PDE
# u_t = (-0.000333 -0.017445i)u_xx-u_yy
#     + (-0.001235 +0.130334i)nx*u-ny*u
#     + (-0.000149 +0.000007i)u
#     + (-0.411834 -7.985677i)u_x^2-u_y^2
#     + (0.422715 +8.152905i)uc_x*u_x-uc_y*u_y
#     + (0.446053 +0.051161i)nx_x*u_y-ny_y*u_x
#
# Error 0.11282694802398577, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 38 from total 128
# Current PDE
# u_t = (-0.000228 -0.115515i)u_xx-u_yy
#     + (-0.000598 +0.119843i)nx*u-ny*u
#     + (-0.000137 +0.000005i)u
#     + (-0.317000 -7.456295i)u_x^2-u_y^2
#     + (0.310506 +7.810437i)uc_x*u_x-uc_y*u_y
#     + (0.000020 -0.030068i)u_xxxx-u_yyyy
#
# Error 0.1104856909492767, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 39 from total 128
# Current PDE
# u_t = (-0.000339 -0.017448i)u_xx-u_yy
#     + (-0.000712 +0.130395i)nx*u-ny*u
#     + (-0.000148 +0.000006i)u
#     + (-0.356828 -7.975756i)u_x^2-u_y^2
#     + (0.350509 +8.141058i)uc_x*u_x-uc_y*u_y
#
# Error 0.10279723923696392, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 40 from total 128
# Current PDE
# u_t = (-0.000553 -0.120303i)u_xx-u_yy
#     + (-0.000877 +0.137586i)nx*u-ny*u
#     + (-0.000221 -0.000002i)u
#     + (-0.002002 +0.162644i)u_x^2-u_y^2
#     + (-0.161714 -15.701829i)nx_x*u_x-ny_y*u_y
#     + (0.178145 -8.497541i)nx_x*u_y-ny_y*u_x
#     + (-0.000054 -0.030759i)u_xxxx-u_yyyy
#
# Error 0.11827377887931723, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 41 from total 128
# Current PDE
# u_t = (-0.000434 -0.020011i)u_xx-u_yy
#     + (-0.000945 +0.149758i)nx*u-ny*u
#     + (-0.000226 -0.000001i)u
#     + (-0.001562 -0.073616i)u_x^2-u_y^2
#     + (-0.206861 -15.589581i)nx_x*u_x-ny_y*u_y
#     + (0.212538 -9.453242i)nx_x*u_y-ny_y*u_x
#
# Error 0.11090240500502464, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 42 from total 128
# Current PDE
# u_t = (-0.000630 -0.123250i)u_xx-u_yy
#     + (-0.000831 +0.129303i)nx*u-ny*u
#     + (-0.000168 -0.000003i)u
#     + (-0.005933 +0.397362i)u_x^2-u_y^2
#     + (-0.211492 -11.924725i)nx_x*u_x-ny_y*u_y
#     + (-0.000070 -0.031750i)u_xxxx-u_yyyy
#
# Error 0.10981545177405452, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 43 from total 128
# Current PDE
# u_t = (-0.000461 -0.019691i)u_xx-u_yy
#     + (-0.000877 +0.140948i)nx*u-ny*u
#     + (-0.000167 -0.000002i)u
#     + (-0.006448 +0.179947i)u_x^2-u_y^2
#     + (-0.270414 -11.368260i)nx_x*u_x-ny_y*u_y
#
# Error 0.10262354384731076, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 44 from total 128
# Current PDE
# u_t = (-0.000207 -0.118085i)u_xx-u_yy
#     + (-0.000805 +0.131091i)nx*u-ny*u
#     + (-0.000005 +0.000002i)u
#     + (-0.007425 +0.147909i)u_x^2-u_y^2
#     + (0.197446 -0.825192i)nx_x*u_y-ny_y*u_x
#     + (0.000044 -0.030523i)u_xxxx-u_yyyy
#
# Error 0.11214660009986133, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 45 from total 128
# Current PDE
# u_t = (-0.000402 -0.018570i)u_xx-u_yy
#     + (-0.000931 +0.143216i)nx*u-ny*u
#     + (-0.000011 +0.000002i)u
#     + (-0.006244 -0.086435i)u_x^2-u_y^2
#     + (0.257097 -1.827713i)nx_x*u_y-ny_y*u_x
#
# Error 0.10441782923945717, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 46 from total 128
# Current PDE
# u_t = (-0.000131 -0.118523i)u_xx-u_yy
#     + (-0.000624 +0.130253i)nx*u-ny*u
#     + (-0.000005 +0.000001i)u
#     + (-0.014213 +0.177531i)u_x^2-u_y^2
#     + (0.000068 -0.030655i)u_xxxx-u_yyyy
#
# Error 0.10223201060683523, Error best: 0.0946361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000199 -0.009289i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.000199 -0.009289i)u_xx-u_yy
#
# iteration 47 from total 128
# Current PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# Error 0.09463025667066616, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 48 from total 128
# Current PDE
# u_t = (-0.000604 -0.120834i)u_xx-u_yy
#     + (-0.000885 +0.137058i)nx*u-ny*u
#     + (-0.000223 -0.000002i)u
#     + (0.005348 +0.278199i)uc_x*u_x-uc_y*u_y
#     + (-0.159531 -15.600497i)nx_x*u_x-ny_y*u_y
#     + (0.194502 -8.185339i)nx_x*u_y-ny_y*u_x
#     + (-0.000071 -0.030950i)u_xxxx-u_yyyy
#
# Error 0.11828481263005741, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 49 from total 128
# Current PDE
# u_t = (-0.000429 -0.019952i)u_xx-u_yy
#     + (-0.000962 +0.149716i)nx*u-ny*u
#     + (-0.000224 -0.000001i)u
#     + (0.006960 +0.044616i)uc_x*u_x-uc_y*u_y
#     + (-0.202784 -15.578349i)nx_x*u_x-ny_y*u_y
#     + (0.229977 -9.224748i)nx_x*u_y-ny_y*u_x
#
# Error 0.11094736977251263, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 50 from total 128
# Current PDE
# u_t = (-0.000669 -0.123779i)u_xx-u_yy
#     + (-0.000800 +0.128779i)nx*u-ny*u
#     + (-0.000176 -0.000003i)u
#     + (-0.001047 +0.552492i)uc_x*u_x-uc_y*u_y
#     + (-0.219323 -11.946498i)nx_x*u_x-ny_y*u_y
#     + (-0.000083 -0.031957i)u_xxxx-u_yyyy
#
# Error 0.10971650436484336, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 51 from total 128
# Current PDE
# u_t = (-0.000458 -0.019572i)u_xx-u_yy
#     + (-0.000854 +0.140813i)nx*u-ny*u
#     + (-0.000171 -0.000002i)u
#     + (-0.000659 +0.346424i)uc_x*u_x-uc_y*u_y
#     + (-0.276862 -11.442401i)nx_x*u_x-ny_y*u_y
#
# Error 0.10257344833565608, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 52 from total 128
# Current PDE
# u_t = (-0.000282 -0.119189i)u_xx-u_yy
#     + (-0.000815 +0.130417i)nx*u-ny*u
#     + (-0.000008 +0.000001i)u
#     + (0.002583 +0.367190i)uc_x*u_x-uc_y*u_y
#     + (0.216660 -0.354772i)nx_x*u_y-ny_y*u_x
#     + (0.000020 -0.030906i)u_xxxx-u_yyyy
#
# Error 0.112166196415796, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 53 from total 128
# Current PDE
# u_t = (-0.000397 -0.018455i)u_xx-u_yy
#     + (-0.000947 +0.143066i)nx*u-ny*u
#     + (-0.000010 +0.000002i)u
#     + (0.005125 +0.133833i)uc_x*u_x-uc_y*u_y
#     + (0.276904 -1.403452i)nx_x*u_y-ny_y*u_x
#
# Error 0.10450018926330763, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 54 from total 128
# Current PDE
# u_t = (-0.000181 -0.119382i)u_xx-u_yy
#     + (-0.000593 +0.130037i)nx*u-ny*u
#     + (-0.000008 +0.000001i)u
#     + (-0.006016 +0.381375i)uc_x*u_x-uc_y*u_y
#     + (0.000051 -0.030964i)u_xxxx-u_yyyy
#
# Error 0.10219559670909839, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 55 from total 128
# Current PDE
# u_t = (-0.000401 -0.018460i)u_xx-u_yy
#     + (-0.000696 +0.141660i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#     + (-0.005543 +0.188458i)uc_x*u_x-uc_y*u_y
#
# Error 0.09464850372837481, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 56 from total 128
# Current PDE
# u_t = (-0.000561 -0.119362i)u_xx-u_yy
#     + (-0.000864 +0.137661i)nx*u-ny*u
#     + (-0.000224 -0.000002i)u
#     + (-0.165114 -15.692648i)nx_x*u_x-ny_y*u_y
#     + (0.183058 -8.794828i)nx_x*u_y-ny_y*u_x
#     + (-0.000056 -0.030448i)u_xxxx-u_yyyy
#
# Error 0.10821187113387287, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 57 from total 128
# Current PDE
# u_t = (-0.000433 -0.019979i)u_xx-u_yy
#     + (-0.000951 +0.149781i)nx*u-ny*u
#     + (-0.000225 -0.000001i)u
#     + (-0.205638 -15.593325i)nx_x*u_x-ny_y*u_y
#     + (0.214917 -9.321095i)nx_x*u_y-ny_y*u_x
#
# Error 0.10093368332198221, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 58 from total 128
# Current PDE
# u_t = (-0.000664 -0.121094i)u_xx-u_yy
#     + (-0.000797 +0.128751i)nx*u-ny*u
#     + (-0.000170 -0.000003i)u
#     + (-0.224167 -11.561123i)nx_x*u_x-ny_y*u_y
#     + (-0.000081 -0.031041i)u_xxxx-u_yyyy
#
# Error 0.09977327614387167, Error best: 0.09463025667066616, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000406 -0.018588i)u_xx-u_yy
#     + (-0.000722 +0.141471i)nx*u-ny*u
#     + (-0.000011 +0.000001i)u
#     + (-0.014677 -0.022786i)u_x^2-u_y^2
#
# iteration 59 from total 128
# Current PDE
# u_t = (-0.000458 -0.019763i)u_xx-u_yy
#     + (-0.000850 +0.140576i)nx*u-ny*u
#     + (-0.000168 -0.000002i)u
#     + (-0.278889 -11.207309i)nx_x*u_x-ny_y*u_y
#
# Error 0.09259549389416444, Error best: 0.09259549389416444, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000458 -0.019763i)u_xx-u_yy
#     + (-0.000850 +0.140576i)nx*u-ny*u
#     + (-0.000168 -0.000002i)u
#     + (-0.278889 -11.207309i)nx_x*u_x-ny_y*u_y
#
# iteration 60 from total 128
# Current PDE
# u_t = (-0.000246 -0.117230i)u_xx-u_yy
#     + (-0.000798 +0.131163i)nx*u-ny*u
#     + (-0.000008 +0.000002i)u
#     + (0.213858 -1.099532i)nx_x*u_y-ny_y*u_x
#     + (0.000031 -0.030241i)u_xxxx-u_yyyy
#
# Error 0.1020744058873771, Error best: 0.09259549389416444, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000458 -0.019763i)u_xx-u_yy
#     + (-0.000850 +0.140576i)nx*u-ny*u
#     + (-0.000168 -0.000002i)u
#     + (-0.278889 -11.207309i)nx_x*u_x-ny_y*u_y
#
# iteration 61 from total 128
# Current PDE
# u_t = (-0.000399 -0.018532i)u_xx-u_yy
#     + (-0.000936 +0.143241i)nx*u-ny*u
#     + (-0.000010 +0.000002i)u
#     + (0.267197 -1.670339i)nx_x*u_y-ny_y*u_x
#
# Error 0.09446229817765535, Error best: 0.09259549389416444, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000458 -0.019763i)u_xx-u_yy
#     + (-0.000850 +0.140576i)nx*u-ny*u
#     + (-0.000168 -0.000002i)u
#     + (-0.278889 -11.207309i)nx_x*u_x-ny_y*u_y
#
# iteration 62 from total 128
# Current PDE
# u_t = (-0.000209 -0.117609i)u_xx-u_yy
#     + (-0.000594 +0.129990i)nx*u-ny*u
#     + (-0.000008 +0.000001i)u
#     + (0.000042 -0.030348i)u_xxxx-u_yyyy
#
# Error 0.09217575833791689, Error best: 0.09217575833791689, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000209 -0.117609i)u_xx-u_yy
#     + (-0.000594 +0.129990i)nx*u-ny*u
#     + (-0.000008 +0.000001i)u
#     + (0.000042 -0.030348i)u_xxxx-u_yyyy
#
# iteration 63 from total 128
# Current PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# Error 0.0846361271901821, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 64 from total 128
# Current PDE
# u_t = (-0.000260 -0.059610i)u_xx-u_yy
#     + (-0.001388 +0.130685i)nx*u-ny*u
#     + (-0.000260 -0.059610i)u_xx-u_yy
#     + (-0.274592 -3.291066i)u_x^2-u_y^2
#     + (0.281057 +3.596237i)uc_x*u_x-uc_y*u_y
#     + (-0.020295 -12.582876i)nx_x*u_x-ny_y*u_y
#     + (0.287800 -6.135081i)nx_x*u_y-ny_y*u_x
#     + (-0.000065 -0.030670i)u_xxxx-u_yyyy
#
# Error 0.12831941068965702, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 65 from total 128
# Current PDE
# u_t = (10915556622336.000000 -85398700032.000000i)u_xx-u_yy
#     + (0.000000 +0.142426i)nx*u-ny*u
#     + (-10915556622336.000000 +85398700032.000000i)u_xx-u_yy
#     + (-0.339722 -3.739672i)u_x^2-u_y^2
#     + (0.350709 +3.816502i)uc_x*u_x-uc_y*u_y
#     + (-0.026154 -12.338741i)nx_x*u_x-ny_y*u_y
#     + (0.361632 -6.973070i)nx_x*u_y-ny_y*u_x
#
# Error 0.12228121854726273, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 66 from total 128
# Current PDE
# u_t = (-0.000302 -0.060329i)u_xx-u_yy
#     + (-0.000980 +0.122692i)nx*u-ny*u
#     + (-0.000302 -0.060329i)u_xx-u_yy
#     + (-0.193511 -4.619236i)u_x^2-u_y^2
#     + (0.191392 +5.122165i)uc_x*u_x-uc_y*u_y
#     + (-0.170577 -9.636939i)nx_x*u_x-ny_y*u_y
#     + (-0.000080 -0.031247i)u_xxxx-u_yyyy
#
# Error 0.11906057442670889, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 67 from total 128
# Current PDE
# u_t = (11068387622912.000000 +217134317568.000000i)u_xx-u_yy
#     + (-0.001953 +0.133545i)nx*u-ny*u
#     + (-11068387622912.000000 -217134317568.000000i)u_xx-u_yy
#     + (-0.240803 -5.262912i)u_x^2-u_y^2
#     + (0.240877 +5.560257i)uc_x*u_x-uc_y*u_y
#     + (-0.214374 -8.976556i)nx_x*u_x-ny_y*u_y
#
# Error 0.11307965716138473, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 68 from total 128
# Current PDE
# u_t = (-0.000208 -0.058161i)u_xx-u_yy
#     + (-0.001120 +0.119743i)nx*u-ny*u
#     + (-0.000208 -0.058161i)u_xx-u_yy
#     + (-0.315086 -6.873702i)u_x^2-u_y^2
#     + (0.321892 +7.264030i)uc_x*u_x-uc_y*u_y
#     + (0.327652 +0.849238i)nx_x*u_y-ny_y*u_x
#     + (-0.000038 -0.030292i)u_xxxx-u_yyyy
#
# Error 0.12066587686404939, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 69 from total 128
# Current PDE
# u_t = (11318285303808.000000 +358348718080.000000i)u_xx-u_yy
#     + (-0.001953 +0.131470i)nx*u-ny*u
#     + (-11318285303808.000000 -358348718080.000000i)u_xx-u_yy
#     + (-0.380198 -7.249515i)u_x^2-u_y^2
#     + (0.391811 +7.412737i)uc_x*u_x-uc_y*u_y
#     + (0.404366 -0.111972i)nx_x*u_y-ny_y*u_x
#
# Error 0.11417214035252118, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 70 from total 128
# Current PDE
# u_t = (-0.000115 -0.057968i)u_xx-u_yy
#     + (-0.000716 +0.120765i)nx*u-ny*u
#     + (-0.000115 -0.057968i)u_xx-u_yy
#     + (-0.283822 -6.779501i)u_x^2-u_y^2
#     + (0.277545 +7.136328i)uc_x*u_x-uc_y*u_y
#     + (0.000019 -0.030170i)u_xxxx-u_yyyy
#
# Error 0.11060428766520762, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 71 from total 128
# Current PDE
# u_t = (11305927835648.000000 +366816591872.000000i)u_xx-u_yy
#     + (0.000000 +0.131470i)nx*u-ny*u
#     + (-11305927835648.000000 -366816591872.000000i)u_xx-u_yy
#     + (-0.334676 -7.259994i)u_x^2-u_y^2
#     + (0.330688 +7.427576i)uc_x*u_x-uc_y*u_y
#
# Error 0.10414701076530877, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 72 from total 128
# Current PDE
# u_t = (-0.000248 -0.060183i)u_xx-u_yy
#     + (-0.001029 +0.136999i)nx*u-ny*u
#     + (-0.000248 -0.060183i)u_xx-u_yy
#     + (-0.003836 +0.190445i)u_x^2-u_y^2
#     + (-0.134463 -14.247575i)nx_x*u_x-ny_y*u_y
#     + (0.140127 -7.774894i)nx_x*u_y-ny_y*u_x
#     + (-0.000041 -0.030822i)u_xxxx-u_yyyy
#
# Error 0.11860770197400208, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 73 from total 128
# Current PDE
# u_t = (10503447379968.000000 -469465923584.000000i)u_xx-u_yy
#     + (-0.001953 +0.149231i)nx*u-ny*u
#     + (-10503447379968.000000 +469465923584.000000i)u_xx-u_yy
#     + (-0.001522 -0.046185i)u_x^2-u_y^2
#     + (-0.171892 -14.105003i)nx_x*u_x-ny_y*u_y
#     + (0.181745 -8.718100i)nx_x*u_y-ny_y*u_x
#
# Error 0.11275152480078741, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 74 from total 128
# Current PDE
# u_t = (-0.000294 -0.061551i)u_xx-u_yy
#     + (-0.000971 +0.129393i)nx*u-ny*u
#     + (-0.000294 -0.061551i)u_xx-u_yy
#     + (-0.006667 +0.403443i)u_x^2-u_y^2
#     + (-0.187889 -11.044466i)nx_x*u_x-ny_y*u_y
#     + (-0.000061 -0.031734i)u_xxxx-u_yyyy
#
# Error 0.10995667667313726, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 75 from total 128
# Current PDE
# u_t = (10499529900032.000000 -327376961536.000000i)u_xx-u_yy
#     + (-0.001953 +0.141052i)nx*u-ny*u
#     + (-10499529900032.000000 +327376961536.000000i)u_xx-u_yy
#     + (-0.005501 +0.185672i)u_x^2-u_y^2
#     + (-0.243405 -10.495622i)nx_x*u_x-ny_y*u_y
#
# Error 0.1042556977827863, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 76 from total 128
# Current PDE
# u_t = (-0.000104 -0.059046i)u_xx-u_yy
#     + (-0.000809 +0.131093i)nx*u-ny*u
#     + (-0.000104 -0.059046i)u_xx-u_yy
#     + (-0.007195 +0.148665i)u_x^2-u_y^2
#     + (0.196386 -0.824470i)nx_x*u_y-ny_y*u_x
#     + (0.000044 -0.030525i)u_xxxx-u_yyyy
#
# Error 0.11214537095569607, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 77 from total 128
# Current PDE
# u_t = (10564899176448.000000 -399378841600.000000i)u_xx-u_yy
#     + (0.000000 +0.143188i)nx*u-ny*u
#     + (-10564899176448.000000 +399378841600.000000i)u_xx-u_yy
#     + (-0.004312 -0.085286i)u_x^2-u_y^2
#     + (0.258602 -1.827402i)nx_x*u_y-ny_y*u_x
#
# Error 0.10581367297888414, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 78 from total 128
# Current PDE
# u_t = (-0.000066 -0.059265i)u_xx-u_yy
#     + (-0.000629 +0.130255i)nx*u-ny*u
#     + (-0.000066 -0.059265i)u_xx-u_yy
#     + (-0.014001 +0.178231i)u_x^2-u_y^2
#     + (0.000067 -0.030657i)u_xxxx-u_yyyy
#
# Error 0.10223081839022305, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 79 from total 128
# Current PDE
# u_t = (10555961114624.000000 -367404482560.000000i)u_xx-u_yy
#     + (0.000000 +0.141418i)nx*u-ny*u
#     + (-10555961114624.000000 +367404482560.000000i)u_xx-u_yy
#     + (-0.012918 -0.021685i)u_x^2-u_y^2
#
# Error 0.09602856815549624, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 80 from total 128
# Current PDE
# u_t = (-0.000274 -0.060385i)u_xx-u_yy
#     + (-0.001033 +0.136464i)nx*u-ny*u
#     + (-0.000274 -0.060385i)u_xx-u_yy
#     + (0.003523 +0.285139i)uc_x*u_x-uc_y*u_y
#     + (-0.134261 -14.129527i)nx_x*u_x-ny_y*u_y
#     + (0.155262 -7.492399i)nx_x*u_y-ny_y*u_x
#     + (-0.000058 -0.030973i)u_xxxx-u_yyyy
#
# Error 0.1186122539978828, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 81 from total 128
# Current PDE
# u_t = (10504179286016.000000 -424497840128.000000i)u_xx-u_yy
#     + (-0.001953 +0.149109i)nx*u-ny*u
#     + (-10504179286016.000000 +424497840128.000000i)u_xx-u_yy
#     + (0.007463 +0.051408i)uc_x*u_x-uc_y*u_y
#     + (-0.169134 -14.096095i)nx_x*u_x-ny_y*u_y
#     + (0.200029 -8.526967i)nx_x*u_y-ny_y*u_x
#
# Error 0.112757367701534, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 82 from total 128
# Current PDE
# u_t = (-0.000314 -0.061764i)u_xx-u_yy
#     + (-0.000944 +0.128863i)nx*u-ny*u
#     + (-0.000314 -0.061764i)u_xx-u_yy
#     + (-0.001348 +0.539428i)uc_x*u_x-uc_y*u_y
#     + (-0.195078 -11.014429i)nx_x*u_x-ny_y*u_y
#     + (-0.000075 -0.031907i)u_xxxx-u_yyyy
#
# Error 0.10986532712117755, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 83 from total 128
# Current PDE
# u_t = (10521922240512.000000 -236167593984.000000i)u_xx-u_yy
#     + (-0.001953 +0.140930i)nx*u-ny*u
#     + (-10521922240512.000000 +236167593984.000000i)u_xx-u_yy
#     + (0.001039 +0.334005i)uc_x*u_x-uc_y*u_y
#     + (-0.249651 -10.534881i)nx_x*u_x-ny_y*u_y
#
# Error 0.10416056701042756, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 84 from total 128
# Current PDE
# u_t = (-0.000141 -0.059596i)u_xx-u_yy
#     + (-0.000820 +0.130420i)nx*u-ny*u
#     + (-0.000141 -0.059596i)u_xx-u_yy
#     + (0.002510 +0.367145i)uc_x*u_x-uc_y*u_y
#     + (0.214515 -0.356200i)nx_x*u_y-ny_y*u_x
#     + (0.000020 -0.030907i)u_xxxx-u_yyyy
#
# Error 0.11216383960874618, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 85 from total 128
# Current PDE
# u_t = (10564036198400.000000 -296655454208.000000i)u_xx-u_yy
#     + (0.000000 +0.143066i)nx*u-ny*u
#     + (-10564036198400.000000 +296655454208.000000i)u_xx-u_yy
#     + (0.007241 +0.133756i)uc_x*u_x-uc_y*u_y
#     + (0.279437 -1.405180i)nx_x*u_y-ny_y*u_x
#
# Error 0.10583850861908728, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 86 from total 128
# Current PDE
# u_t = (-0.000091 -0.059693i)u_xx-u_yy
#     + (-0.000601 +0.130038i)nx*u-ny*u
#     + (-0.000091 -0.059693i)u_xx-u_yy
#     + (-0.006004 +0.381387i)uc_x*u_x-uc_y*u_y
#     + (0.000051 -0.030966i)u_xxxx-u_yyyy
#
# Error 0.1021934790473441, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 87 from total 128
# Current PDE
# u_t = (10559163465728.000000 -263908065280.000000i)u_xx-u_yy
#     + (0.001953 +0.141632i)nx*u-ny*u
#     + (-10559163465728.000000 +263908065280.000000i)u_xx-u_yy
#     + (-0.003524 +0.188455i)uc_x*u_x-uc_y*u_y
#
# Error 0.09597808009131492, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 88 from total 128
# Current PDE
# u_t = (-0.000257 -0.059631i)u_xx-u_yy
#     + (-0.001017 +0.137079i)nx*u-ny*u
# ...
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 92 from total 128
# Current PDE
# u_t = (-0.000123 -0.058617i)u_xx-u_yy
#     + (-0.000803 +0.131166i)nx*u-ny*u
#     + (-0.000123 -0.058617i)u_xx-u_yy
#     + (0.211857 -1.100738i)nx_x*u_y-ny_y*u_x
#     + (0.000031 -0.030242i)u_xxxx-u_yyyy
#
# Error 0.10207217657003681, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 93 from total 128
# Current PDE
# u_t = (10559043928064.000000 -363987304448.000000i)u_xx-u_yy
#     + (-0.001953 +0.143250i)nx*u-ny*u
#     + (-10559043928064.000000 +363987304448.000000i)u_xx-u_yy
#     + (0.265520 -1.671875i)nx_x*u_y-ny_y*u_x
#
# Error 0.09585630615285123, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 94 from total 128
# Current PDE
# u_t = (-0.000105 -0.058807i)u_xx-u_yy
#     + (-0.000602 +0.129990i)nx*u-ny*u
#     + (-0.000105 -0.058807i)u_xx-u_yy
#     + (0.000042 -0.030349i)u_xxxx-u_yyyy
#
# Error 0.09217360037933911, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 95 from total 128
# Current PDE
# u_t = (10559109988352.000000 -357506547712.000000i)u_xx-u_yy
#     + (0.000000 +0.141541i)nx*u-ny*u
#     + (-10559109988352.000000 +357506547712.000000i)u_xx-u_yy
#
# Error 0.08602762016283781, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 96 from total 128
# Current PDE
# u_t = (-0.000520 -0.119220i)u_xx-u_yy
#     + (-0.001388 +0.130685i)nx*u-ny*u
#     + (-0.274592 -3.291066i)u_x^2-u_y^2
#     + (0.281057 +3.596237i)uc_x*u_x-uc_y*u_y
#     + (-0.020295 -12.582876i)nx_x*u_x-ny_y*u_y
#     + (0.287800 -6.135081i)nx_x*u_y-ny_y*u_x
#     + (-0.000065 -0.030670i)u_xxxx-u_yyyy
#
# Error 0.11831941068965701, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 97 from total 128
# Current PDE
# u_t = (-0.000352 -0.019177i)u_xx-u_yy
#     + (-0.001537 +0.142450i)nx*u-ny*u
#     + (-0.322668 -3.722707i)u_x^2-u_y^2
#     + (0.331238 +3.799386i)uc_x*u_x-uc_y*u_y
#     + (-0.036305 -12.347769i)nx_x*u_x-ny_y*u_y
#     + (0.347981 -6.980742i)nx_x*u_y-ny_y*u_x
#
# Error 0.11085313017659976, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 98 from total 128
# Current PDE
# u_t = (-0.000605 -0.120659i)u_xx-u_yy
#     + (-0.000980 +0.122692i)nx*u-ny*u
#     + (-0.193511 -4.619236i)u_x^2-u_y^2
#     + (0.191392 +5.122165i)uc_x*u_x-uc_y*u_y
#     + (-0.170577 -9.636939i)nx_x*u_x-ny_y*u_y
#     + (-0.000080 -0.031247i)u_xxxx-u_yyyy
#
# Error 0.10906057442670888, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 99 from total 128
# Current PDE
# u_t = (-0.000394 -0.018672i)u_xx-u_yy
#     + (-0.001043 +0.133585i)nx*u-ny*u
#     + (-0.226943 -5.247058i)u_x^2-u_y^2
#     + (0.224999 +5.544441i)uc_x*u_x-uc_y*u_y
#     + (-0.217860 -8.982029i)nx_x*u_x-ny_y*u_y
#
# Error 0.10169175687248747, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 100 from total 128
# Current PDE
# u_t = (-0.000415 -0.116322i)u_xx-u_yy
#     + (-0.001120 +0.119743i)nx*u-ny*u
#     + (-0.315086 -6.873702i)u_x^2-u_y^2
#     + (0.321892 +7.264030i)uc_x*u_x-uc_y*u_y
#     + (0.327652 +0.849238i)nx_x*u_y-ny_y*u_x
#     + (-0.000038 -0.030292i)u_xxxx-u_yyyy
#
# Error 0.11066587686404938, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 101 from total 128
# Current PDE
# u_t = (-0.000333 -0.017544i)u_xx-u_yy
#     + (-0.001297 +0.131567i)nx*u-ny*u
#     + (-0.366128 -7.233983i)u_x^2-u_y^2
#     + (0.375315 +7.397018i)uc_x*u_x-uc_y*u_y
#     + (0.396196 -0.115073i)nx_x*u_y-ny_y*u_x
#
# Error 0.10292192466160041, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 102 from total 128
# Current PDE
# u_t = (-0.000229 -0.115936i)u_xx-u_yy
#     + (-0.000716 +0.120765i)nx*u-ny*u
#     + (-0.283822 -6.779501i)u_x^2-u_y^2
#     + (0.277545 +7.136328i)uc_x*u_x-uc_y*u_y
#     + (0.000019 -0.030170i)u_xxxx-u_yyyy
#
# Error 0.10060428766520763, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 103 from total 128
# Current PDE
# u_t = (-0.000338 -0.017544i)u_xx-u_yy
#     + (-0.000840 +0.131432i)nx*u-ny*u
#     + (-0.321522 -7.244851i)u_x^2-u_y^2
#     + (0.315432 +7.412364i)uc_x*u_x-uc_y*u_y
#
# Error 0.0929087497729392, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 104 from total 128
# Current PDE
# u_t = (-0.000496 -0.120365i)u_xx-u_yy
#     + (-0.001029 +0.136999i)nx*u-ny*u
#     + (-0.003836 +0.190445i)u_x^2-u_y^2
#     + (-0.134463 -14.247575i)nx_x*u_x-ny_y*u_y
#     + (0.140127 -7.774894i)nx_x*u_y-ny_y*u_x
#     + (-0.000041 -0.030822i)u_xxxx-u_yyyy
#
# Error 0.10860770197400207, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 105 from total 128
# Current PDE
# u_t = (-0.000418 -0.019865i)u_xx-u_yy
#     + (-0.001108 +0.149186i)nx*u-ny*u
#     + (-0.003214 -0.045741i)u_x^2-u_y^2
#     + (-0.173105 -14.105950i)nx_x*u_x-ny_y*u_y
#     + (0.177266 -8.717873i)nx_x*u_y-ny_y*u_x
#
# Error 0.10118400314123388, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 106 from total 128
# Current PDE
# u_t = (-0.000588 -0.123103i)u_xx-u_yy
#     + (-0.000971 +0.129393i)nx*u-ny*u
#     + (-0.006667 +0.403443i)u_x^2-u_y^2
#     + (-0.187889 -11.044466i)nx_x*u_x-ny_y*u_y
#     + (-0.000061 -0.031734i)u_xxxx-u_yyyy
#
# Error 0.09995667667313726, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 107 from total 128
# Current PDE
# u_t = (-0.000448 -0.019599i)u_xx-u_yy
#     + (-0.001017 +0.141033i)nx*u-ny*u
#     + (-0.007083 +0.186088i)u_x^2-u_y^2
#     + (-0.242753 -10.496655i)nx_x*u_x-ny_y*u_y
#
# Error 0.09271818028548201, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 108 from total 128
# Current PDE
# u_t = (-0.000208 -0.118092i)u_xx-u_yy
#     + (-0.000809 +0.131093i)nx*u-ny*u
#     + (-0.007195 +0.148665i)u_x^2-u_y^2
#     + (0.196386 -0.824470i)nx_x*u_y-ny_y*u_x
#     + (0.000044 -0.030525i)u_xxxx-u_yyyy
#
# Error 0.10214537095569608, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 109 from total 128
# Current PDE
# u_t = (-0.000401 -0.018570i)u_xx-u_yy
#     + (-0.000939 +0.143221i)nx*u-ny*u
#     + (-0.006020 -0.084854i)u_x^2-u_y^2
#     + (0.254688 -1.826735i)nx_x*u_y-ny_y*u_x
#
# Error 0.09441409470569442, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 110 from total 128
# Current PDE
# u_t = (-0.000133 -0.118529i)u_xx-u_yy
#     + (-0.000629 +0.130255i)nx*u-ny*u
#     + (-0.014001 +0.178231i)u_x^2-u_y^2
#     + (0.000067 -0.030657i)u_xxxx-u_yyyy
#
# Error 0.09223081839022304, Error best: 0.0846361271901821, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000692 +0.141521i)nx*u-ny*u
#     + (-0.000010 +0.000001i)u
#
# iteration 111 from total 128
# Current PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# Error 0.08462646547019853, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 112 from total 128
# Current PDE
# u_t = (-0.000548 -0.120771i)u_xx-u_yy
#     + (-0.001033 +0.136464i)nx*u-ny*u
#     + (0.003523 +0.285139i)uc_x*u_x-uc_y*u_y
#     + (-0.134261 -14.129527i)nx_x*u_x-ny_y*u_y
#     + (0.155262 -7.492399i)nx_x*u_y-ny_y*u_x
#     + (-0.000058 -0.030973i)u_xxxx-u_yyyy
#
# Error 0.1086122539978828, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 113 from total 128
# Current PDE
# u_t = (-0.000414 -0.019814i)u_xx-u_yy
#     + (-0.001119 +0.149128i)nx*u-ny*u
#     + (0.005250 +0.051441i)uc_x*u_x-uc_y*u_y
#     + (-0.171301 -14.096975i)nx_x*u_x-ny_y*u_y
#     + (0.193783 -8.527445i)nx_x*u_y-ny_y*u_x
#
# Error 0.10121750923486472, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 114 from total 128
# Current PDE
# u_t = (-0.000628 -0.123527i)u_xx-u_yy
#     + (-0.000944 +0.128863i)nx*u-ny*u
#     + (-0.001348 +0.539428i)uc_x*u_x-uc_y*u_y
#     + (-0.195078 -11.014429i)nx_x*u_x-ny_y*u_y
#     + (-0.000075 -0.031907i)u_xxxx-u_yyyy
#
# Error 0.09986532712117756, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 115 from total 128
# Current PDE
# u_t = (-0.000445 -0.019487i)u_xx-u_yy
#     + (-0.000996 +0.140877i)nx*u-ny*u
#     + (-0.000957 +0.334018i)uc_x*u_x-uc_y*u_y
#     + (-0.249196 -10.535556i)nx_x*u_x-ny_y*u_y
#
# Error 0.09267050447388803, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 116 from total 128
# Current PDE
# u_t = (-0.000282 -0.119193i)u_xx-u_yy
#     + (-0.000820 +0.130420i)nx*u-ny*u
#     + (0.002510 +0.367145i)uc_x*u_x-uc_y*u_y
#     + (0.214515 -0.356200i)nx_x*u_y-ny_y*u_x
#     + (0.000020 -0.030907i)u_xxxx-u_yyyy
#
# Error 0.10216383960874618, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 117 from total 128
# Current PDE
# u_t = (-0.000397 -0.018456i)u_xx-u_yy
#     + (-0.000954 +0.143070i)nx*u-ny*u
#     + (0.005034 +0.133767i)uc_x*u_x-uc_y*u_y
#     + (0.274258 -1.405276i)nx_x*u_y-ny_y*u_x
#
# Error 0.09449606450222228, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 118 from total 128
# Current PDE
# u_t = (-0.000181 -0.119386i)u_xx-u_yy
#     + (-0.000601 +0.130038i)nx*u-ny*u
#     + (-0.006004 +0.381387i)uc_x*u_x-uc_y*u_y
#     + (0.000051 -0.030966i)u_xxxx-u_yyyy
#
# Error 0.09219347904734411, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 119 from total 128
# Current PDE
# u_t = (-0.000401 -0.018460i)u_xx-u_yy
#     + (-0.000706 +0.141661i)nx*u-ny*u
#     + (-0.005532 +0.188464i)uc_x*u_x-uc_y*u_y
#
# Error 0.08464440459350384, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 120 from total 128
# Current PDE
# u_t = (-0.000513 -0.119262i)u_xx-u_yy
#     + (-0.001017 +0.137079i)nx*u-ny*u
#     + (-0.137255 -14.216959i)nx_x*u_x-ny_y*u_y
#     + (0.148555 -8.113776i)nx_x*u_y-ny_y*u_x
#     + (-0.000046 -0.030458i)u_xxxx-u_yyyy
#
# Error 0.09853962814932754, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 121 from total 128
# Current PDE
# u_t = (-0.000417 -0.019845i)u_xx-u_yy
#     + (-0.001110 +0.149202i)nx*u-ny*u
#     + (-0.173182 -14.113047i)nx_x*u_x-ny_y*u_y
#     + (0.182588 -8.637954i)nx_x*u_y-ny_y*u_x
#
# Error 0.09120238117670326, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 122 from total 128
# Current PDE
# u_t = (-0.000625 -0.120911i)u_xx-u_yy
#     + (-0.000936 +0.128834i)nx*u-ny*u
#     + (-0.200050 -10.665346i)nx_x*u_x-ny_y*u_y
#     + (-0.000073 -0.031013i)u_xxxx-u_yyyy
#
# Error 0.08991525956121758, Error best: 0.08462646547019853, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000405 -0.018588i)u_xx-u_yy
#     + (-0.000732 +0.141475i)nx*u-ny*u
#     + (-0.014496 -0.021282i)u_x^2-u_y^2
#
# iteration 123 from total 128
# Current PDE
# u_t = (-0.000445 -0.019673i)u_xx-u_yy
#     + (-0.000990 +0.140648i)nx*u-ny*u
#     + (-0.251431 -10.325463i)nx_x*u_x-ny_y*u_y
#
# Error 0.0826899373248223, Error best: 0.0826899373248223, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000445 -0.019673i)u_xx-u_yy
#     + (-0.000990 +0.140648i)nx*u-ny*u
#     + (-0.251431 -10.325463i)nx_x*u_x-ny_y*u_y
#
# iteration 124 from total 128
# Current PDE
# u_t = (-0.000246 -0.117234i)u_xx-u_yy
#     + (-0.000803 +0.131166i)nx*u-ny*u
#     + (0.211857 -1.100738i)nx_x*u_y-ny_y*u_x
#     + (0.000031 -0.030242i)u_xxxx-u_yyyy
#
# Error 0.09207217657003681, Error best: 0.0826899373248223, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000445 -0.019673i)u_xx-u_yy
#     + (-0.000990 +0.140648i)nx*u-ny*u
#     + (-0.251431 -10.325463i)nx_x*u_x-ny_y*u_y
#
# iteration 125 from total 128
# Current PDE
# u_t = (-0.000399 -0.018532i)u_xx-u_yy
#     + (-0.000943 +0.143244i)nx*u-ny*u
#     + (0.264736 -1.671980i)nx_x*u_y-ny_y*u_x
#
# Error 0.08445827865127217, Error best: 0.0826899373248223, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000445 -0.019673i)u_xx-u_yy
#     + (-0.000990 +0.140648i)nx*u-ny*u
#     + (-0.251431 -10.325463i)nx_x*u_x-ny_y*u_y
#
# iteration 126 from total 128
# Current PDE
# u_t = (-0.000210 -0.117613i)u_xx-u_yy
#     + (-0.000602 +0.129990i)nx*u-ny*u
#     + (0.000042 -0.030349i)u_xxxx-u_yyyy
#
# Error 0.0821736003793391, Error best: 0.0821736003793391, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000210 -0.117613i)u_xx-u_yy
#     + (-0.000602 +0.129990i)nx*u-ny*u
#     + (0.000042 -0.030349i)u_xxxx-u_yyyy
#
# iteration 127 from total 128
# Current PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000702 +0.141522i)nx*u-ny*u
#
# Error 0.07463202487392147, Error best: 0.07463202487392147, l0_penalty: 0.01, pde:
# Best PDE
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000702 +0.141522i)nx*u-ny*u
#
# u_t = (-0.000398 -0.018577i)u_xx-u_yy
#     + (-0.000702 +0.141522i)nx*u-ny*u
#
# Time elapsed 0.2755110263824463

# %%
# evaluate obtained PDE

import functions_PDE_solver
reload( functions_PDE_solver )
from functions_PDE_solver import *

nskip = 10

# select part to evolve (upper-right quarter correlations)
u_int = u[:,:,:]

coefs = train_data_t[0]

# initial condition
t_rec = np.array(t)[:it_end]
u0 = u_int[0,:,:]
#v0 = (u_int[it_start] - u_int[it_start-1])/(t[1]-t[0])
#coefs = np.array([[-1j*J_eff],[0.]])
u_test = scalar_pde_solver(descr_select, coefs, u0, t_rec, dx, Q=None, v0=None, dirichlet_bc=None, bc="open", nskip=nskip)

# %%
# plot comparison

ind_t = -1
ind_x = range(N_site//2,N_site,10)

# ground truth
u_true = u_int[:,:,:]

# densities
n_test = np.zeros((u_test.shape[0],u_test.shape[1]))
n_true = np.zeros((u_true.shape[0],u_true.shape[1]))
for i in range(N_site):
  n_test[:,i] = u_test[:,i,i]
  n_true[:,i] = u_true[:,i,i]

# the figure
fig, ax = plt.subplots(2,2, figsize=(12,12))

ax[0,0].plot(n_true[ind_t,:].T,"k", linewidth=1.3, label="ground truth")
_=ax[0,0].plot(n_test[ind_t,:].T,"b--", linewidth=.8, label="recovered PDE")
ax[0,0].set_title('final density')
ax[0,0].legend()
ax[0,0].set_xlabel('i')

ax[0,1].plot(np.real(u_true)[ind_t,N_site//2, :].T,"k", linewidth=1.3, label="ground truth")
_=ax[0,1].plot(np.real(u_test)[ind_t,N_site//2, :].T,"b--", linewidth=.8, label="recovered PDE")
ax[0,1].set_title('final correlation')
ax[0,1].set_xlabel('|i-j|')

ax[1,0].plot(t_rec*J,n_true[it_start:it_end,ind_x],"k", linewidth=1.3)
_=ax[1,0].plot(t_rec*J,n_test[:,ind_x],"b--", linewidth=.8)
ax[1,0].set_title('densities in time')
ax[1,0].set_xlabel('tJ')

ax[1,1].plot(t_rec*J,np.real(u_true)[it_start:it_end,N_site//2,ind_x],"k", linewidth=1.3)
_=ax[1,1].plot(t_rec*J,np.real(u_test)[:,N_site//2,ind_x],"b--", linewidth=.8)
ax[1,1].set_title('correlations in time')
ax[1,1].set_xlabel('tJ')

for va in ax:
  for a in va:
    a.grid(True)
# Out:
# <ipython-input-66-122d188c9ca6>:13: ComplexWarning: Casting complex values to real discards the imaginary part
#   n_test[:,i] = u_test[:,i,i]
# <ipython-input-66-122d188c9ca6>:14: ComplexWarning: Casting complex values to real discards the imaginary part
#   n_true[:,i] = u_true[:,i,i]
